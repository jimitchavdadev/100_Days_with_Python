# %%
# rock, paper and scissor code

import os
import random

def clear_console():
    os.system('cls' if os.name == 'nt' else 'clear')

user_score = 0
comp_score = 0

print("Press 'q' followed by Enter to exit")

while True:
    user_input = input("Type your choice (0 for Rock, 1 for Paper, 2 for Scissors) or 'q' to quit: ")
    if user_input == 'q':  # Check if the input is 'q'
        print("Exiting...")
        break  # Exit the loop

    if user_input not in ['0', '1', '2']:
        print("Invalid input, please enter 0, 1, 2, or 'q'.")
        continue
    
    number = int(user_input)
    comp_choice = random.randint(0, 2)

    choices = ["Rock", "Paper", "Scissors"]

    print(f"You chose: {choices[number]}")
    print(f"Computer chose: {choices[comp_choice]}")

    if number == comp_choice:
        print("It's a tie!")
    elif (number == 0 and comp_choice == 2) or (number == 1 and comp_choice == 0) or (number == 2 and comp_choice == 1):
        user_score += 1
        print("You win this round!")
    else:
        comp_score += 1
        print("Computer wins this round!")

    print(f"Your score: {user_score}")
    print(f"Computer's score: {comp_score}")

    clear_console()
# Out:
# Press 'q' followed by Enter to exit
# You chose: Rock
# Computer chose: Rock
# It's a tie!
# Your score: 0
# Computer's score: 0
# You chose: Paper
# Computer chose: Scissors
# Computer wins this round!
# Your score: 0
# Computer's score: 1
# You chose: Scissors
# Computer chose: Rock
# Computer wins this round!
# Your score: 0
# Computer's score: 2
# You chose: Paper
# Computer chose: Rock
# You win this round!
# Your score: 1
# Computer's score: 2
# You chose: Scissors
# Computer chose: Rock
# Computer wins this round!
# Your score: 1
# Computer's score: 3
# You chose: Paper
# Computer chose: Paper
# It's a tie!
# Your score: 1
# Computer's score: 3
# You chose: Paper
# Computer chose: Paper
# It's a tie!
# Your score: 1
# Computer's score: 3
# You chose: Paper
# Computer chose: Rock
# You win this round!
# Your score: 2
# Computer's score: 3
# You chose: Rock
# Computer chose: Rock
# It's a tie!
# Your score: 2
# Computer's score: 3
# You chose: Paper
# Computer chose: Rock
# ...

# %%
# head and tails

import random

num=random.randint(0,1)

if num==0:
    print("heads")
else:
    print("tails")
# Out:
# heads

# %%
fruits=["apple","banana"]
print(fruits)
# Out:
# ['apple', 'banana']

# %%
# Banker's roulette 

import random

names_string=input("enter the name of people: ")

bankers=names_string.split(", ")

name=bankers[random.randint(0,len(bankers)-1)]

print(f"{name} has to pay the bill")

# Alternative code
"""
name=random.choice(bankers)
"""
# Out:
# mike has to pay the bill

# %%
# Treasure Map

row1=["","",""]
row2=["","",""]
row3=["","",""]

Treasure_list=[row1,row2,row3]


print("where do you want to put the treasure? ")

value=(input("enter the value of the place: "))

row = int(value[0])
col = int(value[1])

Treasure_list[row][col]="🪙"

print(f"{Treasure_list[0]}\n{Treasure_list[1]}\n{Treasure_list[2]}")
# Out:
# where do you want to put the treasure?
# ['', '', '']
# ['', '', '']
# ['', '', '🪙']
